# %% [markdown]
# ![VLC-00005.png](data:image/png;base64,...)

# %% [markdown]
# Циклы, функции, numpy

# %% [markdown]
# 0. Один игрок загадывает число от 1 до 10: вводится с клавиатуры. Второй отгадывает, пока не отгадает. На экран выводится правильно, неправильно.
# Пример:
#
# Введите число: 7
# ***
# ***
# ***
#
# Введите число от 1 до 10
#
# Игрок 2: 4
#
# Неправильно
#
# Введите число от 1 до 10
#
# Игрок 2: 7
#
# Правильно!
#
# Вы победили

# %% [markdown]
# 1. Улучшите код. В каждой итерации цикла программа должна предоставлять пользователю подсказки о том, больше или меньше введенное число, чем загаданное число.

# %% [markdown]
# 1*.  Напишите камень: ножницы: бумага на Python

# %% [markdown]
# 3. Создайте функцию, которая будет принимать на вход имя пользователя и возраст и будет выводить приветствие в формате "Привет, {имя}. Тебе уже {возраст} лет!

# %% [markdown]
# 4. Напишите функцию, которая будет принимать на вход список чисел и печатать те, которые больше 5.

# %% [markdown]
# 5. Создайте функцию, которая будет принимать два аргумента - длину и высоту стены в метрах. Функция должна вычислять площадь стены в квадратных метрах и печатать результат.

# %% [markdown]
# 6. Создайте функцию, которая будет принимать на вход два числа и делить первое на второе. Если второе значение равно 0, функция должна печатать "На ноль делить нельзя!".

# %% [markdown]
# 7. Напишите цикл for, в котором будут выводиться на экран квадраты всех чисел от 1 до 10.

# %% [markdown]
# 8.Создайте цикл for, который будет выводить на экран все четные числа от 4 до 23.

# %% [markdown]
# 9. Создайте многомерный массив numpy размером 2 на 3, состоящий из чисел 1, 2 и 3.
#
# [[1,2,3][1,2,3]]

# %% [markdown]
# 10. Создайте массив numpy размером 24 и измените его форму на 3 на 8.
# Для того, чтобы создать массив от 0 до 23
#
# num_array = np.arange(24)
