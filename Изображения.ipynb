# %% [markdown]
# Чтобы поработать с этой тетрадкой нажми файл -> сохранить копию на диске!

# %% [markdown]
# Сегодня мы будем с вами научимся распознавать объекты на фотографиях с помощью нейросетей.

# %% [markdown]
# # 0. Настройка
#
# Тут мы скачиваем и устанавливаем важные вещи.
# Это надо просто запустить, нажав на кнопку
# ![image.png](data:image/png;base64,...)

# %%
# !git clone https://github.com/sofiatrucunenko/yolov5_test.git # clone
# %cd yolov5_test
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 1c4eae5 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %% [markdown]
# #1. Возьмем картинку с котом

# %% [markdown]
# ![kitten.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Мы подготовили для вас картинку с котом, она уже находится в тех файлах, которые мы скачали

# %% [markdown]
# #2. Найдем картинку

# %% [markdown]
# Уже тут, нажмите слева на иконку папки

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Если у вас вот так, все хорошо. Если не так, то нажмите на иконку еще раз, запустите еще раз пункт 0, вернитесь сюда и снова нажмите на иконку файлов

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Если вы раскроете папку yolov5 (название нашей модели), раскроете папку data (мы же тут занимаемся data science) и раскроете папку images (картинки). Вы увидите три картинки
# Kitten - та, которая нас интересует

# %% [markdown]
# # 3. Узнаем, что на картинке
#
# Запустим ячейку снизу. Тут мы просто запускаем модель с настройками и даем ей наши картинки (которые лежат в папке images)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1c4eae5 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/6 /content/yolov5_test/data/images/apples.jpg: 384x640 17 apples, 43.7ms
# image 2/6 /content/yolov5_test/data/images/bus.jpg: 640x480 4 persons, 1 bus, 43.1ms
# image 3/6 /content/yolov5_test/data/images/capibara.jpg: 480x640 1 bear, 44.3ms
# image 4/6 /content/yolov5_test/data/images/dog.jpg: 320x640 1 dog, 42.6ms
# ...

# %% [markdown]
# Обратите внимание на вывод: по каждой картинке в папке, мы уже можем увидеть, что наша модель нашла. На нашей картинке с котиком, нейросеть определенно нашла кота!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Любуемся результатом

# %% [markdown]
# Замените в коде ниже bus.jpg на kitten.jpg, чтобы найти нашего котенка!

# %%
display.Image(filename='runs/detect/exp2/capibara.jpg', width=600)

# %% [markdown]
# Если вы правильно все сделали и запустили код, то поздравляем вас, вы смогли самостоятельно найти кошку и распознать ее с помощью нейросетей!

# %% [markdown]
# #Результат!
#
#
# ![Без названия (2).jfif](data:image/jpeg;base64,...)
